# %%
import pandas as pd

# %%
msleep = pd.read_csv("./msleep.csv")

# %%
data = ["name", "genus"]
msleep[data]
# Out:
#          genus
# 0     Acinonyx
# 1        Aotus
# 2   Aplodontia
# 3      Blarina
# 4          Bos
# ..         ...
# 78      Tupaia
# 79    Tursiops
# 80     Genetta
# 81      Vulpes
# 82      Vulpes
#
# [83 rows x 1 columns]
